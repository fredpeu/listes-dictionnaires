# %% [markdown]
# # <div align="center">RAPPELS DE PREMIÈRE: EXERCICES</div>
# <br>

# %% [markdown]
# ## CALCUL D´UN MOYENNE

# %%
marta= [10, 15, 11, 18, 7, 12, 13, 16, 18]
tiago= [8, 11, 12, 14, 10, 9, 15, 12, 11,13,18]

# %% [markdown]
# <br>*Compléter la fonction `moyenne(liste)` qui permet de calculer la moyenne d´un élève arrondie au dixième.*

# %%
# code

# %%
moyenne(marta)

# %%
moyenne(tiago)

# %% [markdown]
# <br>*Tiago a obtenu un **14** et Marta un **16***. Comment ajouter ces deux nouvelles notes aux listes?

# %%
# code

# %% [markdown]
# <br>*Le professeur décide de cocher la case "enlever la plus mauvaise note". A l´aide de la fonction `indexMini` (à compléter), affichez la moyenne corrigée de Marta et Tiago.*

# %% [markdown]
# http://www.fredpeuriere.com/NSI/algos-1/algorithmes-illustres/min.html

# %%
def indexMini(liste):  
    """détermination de l´indice 
    de la plus mauvaise note"""  
    pass

# %%
# MARTA

# %%
# TIAGO

# %% [markdown]
# ## COMPREHENSIONS ET STRUCTURES IMBRIQUEES

# %% [markdown]
# <br>Si liste désigne la liste `[1, [2, 3], [4, 5], 6, 7]`, que vaut `len(liste)` ?

# %%
liste=[1, [2, 3], [4, 5], 6, 7]
# test

# %% [markdown]
# <br>Que vaut `[2 * n for n in range(5)]` ?

# %%
# test

# %% [markdown]
# <br>Supposons que `liste = [-5, 2, 3, -7, 42, 7]`. Que vaut `[n for n in liste if n > 0]` ?

# %%
# test

# %% [markdown]
# ## CARRÉ MAGIQUE

# %% [markdown]
# <br>Un carré est magique si les sommes de ses lignes, colonnes et diagonales sont égales.

# %%
carre3=[
    [2,7,6],
    [9,5,1],
    [4,3,8],
]

carre4=[
    [4,5,11,14],
    [15,10,8,1],
    [6,3,13,12],
    [9,16,2,7]
]

# %% [markdown]
# > Quelle est la valeur de `len(carre4)` ? <br>
# > Quelle est la valeur de `carre3[0][2]`? <br>
# > Quelle instruction permet de récupérer la valeur 3 de `carre4` ?
# <img src="http://www.fredpeuriere.com/NSI/5/carre.png" width='300'>

# %%
# tests

# %%
def ligne(carre,n):
    """retourne la somme des nombres
    d´une ligne"""
    somme=0
    for i in carre[n]:
        somme+=i
    return somme

# %% [markdown]
# <br>Que vaut `ligne(carre4, 2)` ? À quoi sert cette fonction ?

# %%
# test

# %%
# test avec le carre3, première ligne

# %% [markdown]
# <br>Écrire le code d’une fonction `sommeLignes` qui prend un carré en paramètre et qui ajoute dans une liste la somme des nombres de chaque ligne.

# %%
# réponse

# %%
# test avec le carre3

# %%
# test avec le carre4

# %% [markdown]
# <br>Proposer le code d’une fonction `colonne` qui prend un carré en paramètre, ainsi que le numéro d’une colonne, et qui renvoie la somme des nombres de cette colonne.<br>
# <img src="http://www.fredpeuriere.com/NSI/5/carre.png" width='300'>

# %%
# réponse

# %%
# test avec le carre4, deuxième colonne

# %% [markdown]
# <br>Écrire le code d’une fonction `sommeColonnes` qui prend un carré en paramètre et qui ajoute dans une liste la somme des nombres de chaque colonne.

# %%
# réponse
# Out:
# 34
# 34
# 34
# 34

# %% [markdown]
# <br>Pour info, la somme des diagonales:

# %%
def somme_diagonales (carre):
    somme1,somme2 = 0,0
    for i in range(len(carre)):
        somme1+=carre[i][i]
        somme2+=carre[i][len(carre)-1-i]
    return somme1,somme2
somme_diagonales(carre3)
# Out:
# (15, 15)

# %% [markdown]
# ## DICTIONNAIRES: AU ZOO
# Au jardim zoologico de Lisbonne, il y a 5 éléphants d’Asie, 17 écureuils d’Asie, 2 pandas d’Asie… On représente cet inventaire à l’aide d’un dictionnaire, de la façon suivante :

# %%
lisboa={ 'éléphant': ('Asie', 5),  'écureuil': ('Asie', 17), 
            'panda': ('Asie', 2), 'hippopotame': ('Afrique', 7),  
            'girafe': ('Afrique', 4)}

# %% [markdown]
# On représente de la même façon le zoo de Porto:

# %%
porto = { 'ours': ('Europe', 4),  'tigre': ('Asie', 7), 
             'girafe': ('Afrique', 11), 'hippopotame': ('Afrique', 3)}

# %% [markdown]
# On souhaite créer la fonction `plusGrand` qui prend un zoo en paramètre et qui renvoie le nom de l’animal le plus représenté dans ce zoo. Par exemple :
# > plusGrand (porto) --> 'girafe'<br>
# > plusGrand (lisboa) --> 'écureuil'

# %%
# test
porto
# Out:
# {'ours': ('Europe', 4), 'tigre': ('Asie', 7), 'girafe': ('Afrique', 11), 'hippopotame': ('Afrique', 3)}

# %% [markdown]
# a. Quel type de boucle peut-on envisager pour le code de cette fonction ? <br><br>
# <span>☐ `for i in dico.keys()`       ☐ `for i in dico.values()`    <br>   ☐ `for (i,j) in dico.items()`       ☐ `Aucune boucle.`</span>

# %% [markdown]
#   b. Écrire et tester le code de cette fonction.

# %%
# reponse

# %% [markdown]
#  2. On souhaite créer une fonction `total` qui prend un zoo en paramètre ainsi que le nom d’un continent, et qui renvoie le nombre d’animaux originaires de ce continent dans le zoo. Par exemple :<br>
# > total (porto, 'Afrique') --> 14 <br>
# > total (lisboa, 'Asie') --> 24

# %% [markdown]
# a. Quel type de boucle peut-on envisager pour le code de cette fonction ? <br><br>
# <span>☐ `for i in dico.keys()`       ☐ `for i in dico.values()`    <br>   ☐ `for (i,j) in dico.items()`       ☐ `Aucune boucle.`</span>

# %% [markdown]
#   b. Écrire et tester le code de cette fonction.

# %%
# reponse

# %% [markdown]
# 3. On souhaite créer une fonction `nombre` qui prend un zoo en paramètre ainsi que le nom d’un animal, et qui renvoie le nombre de représentants de cet animal dans le zoo.
# Par exemple :  <br>
# > nombre (porto, 'panda') --> 0<br>
# > nombre (lisboa, 'panda') --> 2

# %% [markdown]
# a. Quel type de boucle peut-on envisager pour le code de cette fonction ? <br><br>
# <span>☐ `for i in dico.keys()`       ☐ `for i in dico.values()`    <br>   ☐ `for (i,j) in dico.items()`       ☐ `Aucune boucle.`</span>

# %%
# test

# %% [markdown]
#   b. Écrire et tester le code de cette fonction.

# %%
# reponse
